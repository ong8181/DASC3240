# %% [markdown]
# Github repository is here: https://github.com/ong8181/DASC3240

# %% [markdown]
# ## Reference and datasets
# - Rdatasets v1.0.0 (https://vincentarelbundock.github.io/Rdatasets/)
# - https://vincentarelbundock.github.io/Rdatasets/doc/datasets/ChickWeight.csv
# - https://vincentarelbundock.github.io/Rdatasets/doc/datasets/chickwts.csv
# - https://vincentarelbundock.github.io/Rdatasets/csv/datasets/InsectSprays.csv

# %% [markdown]
# # Assignments
# - `ChickWeight`
#   1. Create a simple histogram of `weight`. Please use all data.
#   1. Exclude data with `Time < 10` and create histogram of `weight` for each `Diet`. There are four histograms, but please combine the four histograms into one figure.
#   1. Draw the four histograms in a separate penel and combine them in a 2 x 2 format. There will be four facets in one large figure and each histogram should be in each facet.
# - `chickwts`
#   1. Create histogram of `weight` for each `feed`. There are four histograms, but please combine the four histograms into one figure.
# - `InsectSprays`
#   1. Create histogram of `count` for each `spray`. There are four histograms, but please combine the four histograms into one figure.
# - Please discuss what is how we can effectively visualize the effect of `Diet`, `feed`, or `spray`. Please implement better visualizations and share them with your colleagues.

# %% [markdown]
# # Preparation

# %%
# Import pandas
import pandas as pd

# %%
# Import data
d1 = pd.read_csv("data/ChickWeight.csv")
d2 = pd.read_csv("data/chickwts.csv")
d3 = pd.read_csv("data/InsectSprays.csv")

# %%
d1

# %%
d2

# %%
d3

# %% [markdown]
# # Assignments: `ChickWeight`

# %% [markdown]
# ### 1. Create a simple histogram of `weight`. Please use all data.

# %% [markdown]
# ### 2. Exclude data with `Time < 10` and create histogram of `weight` for each `Diet`. There are four histograms, but please combine the four histograms into one figure.

# %% [markdown]
# ### 3. Draw the four histograms in a separate penel and combine them in a 2 x 2 format. There will be four facets in one large figure and each histogram should be in each facet.

# %% [markdown]
# # Assignments: `chickwts`

# %% [markdown]
# ### 1. Create histogram of `weight` for each `feed`. Please combine the four histograms into one figure.

# %% [markdown]
# # Assignments: `InsectSprays`

# %% [markdown]
# ### 1. Create histogram of `count` for each `spray`. Please combine the four histograms into one figure.

# %% [markdown]
# # Please discuss what is how we can effectively visualize the effect of Diet, feed, or spray. Please implement better visualizations and share them with your colleagues.
