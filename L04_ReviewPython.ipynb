# %% [markdown]
# Script source
# The original scripts are here: https://thejacksonlaboratory.github.io/python-ecology-lesson/00-short-introduction-to-Python/ ("Python for ecologists: Short Introduction to Programming in Python" CC-BY 4.0). The scripts are modified for this guest lecture and hands-on.

# %% [markdown]
# # Overview
# ## Questions
# - What is Python?
# - Why should I learn Python?
#
# ## Objectives
# - Describe the advantages of using programming vs. completing repetitive tasks by hand.
# - Define the following data types in Python: strings, integers, and floats.
# - Perform mathematical operations in Python using basic operators.
# - Define the following as it relates to Python: lists, tuples, and dictionaries.

# %% [markdown]
# # Getting started with Python and jupyter notebook in Github
#
# In this course, we will use Python from Google Colab (written using jupyter notebook). I uploaded Python codes in Github. Here we start from a quick review of Python.

# %%
# Check Python version we are using
## Note: Software version is **very** important because the code behavior depends on the version. Please always check them and record if possible.

import sys
print(sys.version)
# Out:
# 3.9.16 | packaged by conda-forge | (feeb267e, Jan 18 2023, 16:17:35)
# [PyPy 7.3.11 with GCC Clang 14.0.6]

# %%
# Calculate something
2 + 2
# Out:
# 4

# %%
# Print something
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Introduction to Python built-in data types
# ## Strings, integers and floats
# The most basic data types in Python are strings, integers and floats:

# %%
text = "Data Carpentry"
number = 42
pi_value = 3.1415

# %% [markdown]
# Here we’ve assigned data to variables, namely `text`, `number` and `pi_value`, using the assignment operator =. The variable called `text` is a string which means it can contain letters and numbers. Notice that in order to define a string you need to have quotes around your text. To print out the value stored in a variable we can simply type the name of the variable into the interpreter:

# %%
text
# Out:
# 'Data Carpentry'

# %%
number
# Out:
# 42

# %%
pi_value
# Out:
# 3.1415

# %% [markdown]
# however, in scripts we must use the `print` function:

# %% [markdown]
# # Operators
# We can perform mathematical calculations in Python using the basic operators `+`, `-`, `/`, `*`, `%`:
#
# Please type `2 + 2`, `6 * 7`, `2 ** 3"`, and `13 % 5` in the cell below and check the results.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# We can also use comparison and logic operators: `<`, `>`, `==`, `!=`, `<=`, `>=` and statements of identity such as `and`, `or`, `not`. The data type returned by this is called a boolean.

# %% [markdown]
# 3 > 4
